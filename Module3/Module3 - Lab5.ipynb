# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
# .. your code here ..
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# This is new
from pandas.tools.plotting import andrews_curves

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %%
dataset="C:/Users/zhang/DAT210x/Module3/Datasets/Wheat.data"
df = pd.read_csv(dataset)
df1=df.loc[: ,['compactness','length','width','asymmetry','groove','wheat_type']]
df2=df.loc[: ,['area', 'perimeter','compactness','length','width','asymmetry','groove','wheat_type']]

# %%
df1
# Out:
#      compactness  length  width  asymmetry  groove wheat_type
# 0         0.8710   5.763  3.312     2.2210   5.220       kama
# 1         0.8811   5.554  3.333     1.0180   4.956       kama
# 2         0.9050   5.291  3.337     2.6990   4.825       kama
# 3         0.8955   5.324  3.379     2.2590   4.805       kama
# 4         0.9034   5.658  3.562     1.3550   5.175       kama
# 5         0.8951   5.386  3.312     2.4620   4.956       kama
# 6         0.8799   5.563  3.259     3.5860   5.219       kama
# 7         0.8911   5.420  3.302     2.7000     NaN   canadian
# 8         0.8747   6.053  3.465     2.0400   5.877       kama
# 9         0.8880   5.884  3.505     1.9690   5.533       kama
# 10        0.8696   5.714  3.242     4.5430   5.314       kama
# 11        0.8796   5.438  3.201     1.7170   5.001       kama
# 12        0.8880   5.439  3.199     3.9860   4.738       kama
# 13        0.8759   5.479  3.156     3.1360   4.872       kama
# ...

# %%
df2
# Out:
#       area  perimeter  compactness  length  width  asymmetry  groove  \
# 0    15.26      14.84       0.8710   5.763  3.312     2.2210   5.220
# 1    14.88      14.57       0.8811   5.554  3.333     1.0180   4.956
# 2    14.29      14.09       0.9050   5.291  3.337     2.6990   4.825
# 3    13.84      13.94       0.8955   5.324  3.379     2.2590   4.805
# 4    16.14      14.99       0.9034   5.658  3.562     1.3550   5.175
# 5    14.38      14.21       0.8951   5.386  3.312     2.4620   4.956
# 6    14.69      14.49       0.8799   5.563  3.259     3.5860   5.219
# 7    14.11      14.10       0.8911   5.420  3.302     2.7000     NaN
# 8    16.63      15.46       0.8747   6.053  3.465     2.0400   5.877
# 9    16.44      15.25       0.8880   5.884  3.505     1.9690   5.533
# 10   15.26      14.85       0.8696   5.714  3.242     4.5430   5.314
# 11   14.03      14.16       0.8796   5.438  3.201     1.7170   5.001
# 12   13.89      14.02       0.8880   5.439  3.199     3.9860   4.738
# ...

# %%
plt.figure()
andrews_curves(df1, 'wheat_type',alpha=0.4)
plt.show()

# %%
plt.figure()
andrews_curves(df2, 'wheat_type',alpha=0.4)
plt.show()
